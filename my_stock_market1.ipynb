# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#dession tree

# %%
dataset = pd.read_csv('FB JAN-JULY.csv')

# %%
dataset
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-01-02  206.750000  209.789993  206.270004  209.779999  209.779999
# 1    2020-01-03  207.210007  210.399994  206.949997  208.669998  208.669998
# 2    2020-01-06  206.699997  212.779999  206.520004  212.600006  212.600006
# 3    2020-01-07  212.820007  214.580002  211.750000  213.059998  213.059998
# 4    2020-01-08  213.000000  216.240005  212.610001  215.220001  215.220001
# ..          ...         ...         ...         ...         ...         ...
# 122  2020-06-26  232.639999  233.089996  215.399994  216.080002  216.080002
# 123  2020-06-29  209.750000  220.750000  207.110001  220.639999  220.639999
# 124  2020-06-30  220.589996  227.500000  218.470001  227.070007  227.070007
# 125  2020-07-01  228.500000  239.000000  227.559998  237.550003  237.550003
# 126  2020-07-02  239.000000  240.000000  232.610001  233.419998  233.419998
#
#        Volume
# 0    12077100
# 1    11188400
# ...

# %%
X = dataset.iloc[:, 1:-3].values

# %%
X
# Out:
# array([[206.75    , 209.789993, 206.270004],
#        [207.210007, 210.399994, 206.949997],
#        [206.699997, 212.779999, 206.520004],
#        [212.820007, 214.580002, 211.75    ],
#        [213.      , 216.240005, 212.610001],
#        [217.539993, 218.380005, 216.279999],
#        [219.199997, 219.880005, 217.419998],
#        [219.600006, 221.970001, 219.210007],
#        [221.610001, 222.380005, 218.630005],
#        [220.610001, 221.679993, 220.139999],
#        [222.570007, 222.630005, 220.389999],
#        [222.029999, 222.289993, 220.529999],
#        [222.160004, 222.369995, 219.119995],
#        [222.309998, 222.75    , 221.279999],
#        [220.75    , 221.490005, 219.270004],
#        [220.800003, 221.779999, 216.110001],
#        [213.100006, 216.059998, 212.5     ],
#        [216.139999, 218.740005, 213.520004],
#        [221.440002, 224.199997, 218.449997],
#        [206.529999, 211.429993, 204.75    ],
#        [208.429993, 208.690002, 201.059998],
# ...

# %%
y = dataset.iloc[:, -3:-2].values

# %%
y
# Out:
# array([[209.779999],
#        [208.669998],
#        [212.600006],
#        [213.059998],
#        [215.220001],
#        [218.300003],
#        [218.059998],
#        [221.910004],
#        [219.059998],
#        [221.149994],
#        [221.770004],
#        [222.139999],
#        [221.440002],
#        [221.320007],
#        [219.759995],
#        [217.940002],
#        [214.869995],
#        [217.789993],
#        [223.229996],
#        [209.529999],
#        [201.910004],
#        [204.190002],
#        [209.830002],
#        [210.110001],
#        [210.850006],
#        [212.330002],
#        [213.059998],
#        [207.190002],
#        [210.759995],
#        [213.139999],
#        [214.179993],
#        [217.800003],
#        [217.490005],
#        [214.580002],
#        [210.179993],
#        [200.720001],
#        [196.770004],
#        [197.199997],
#        [189.75    ],
#        [192.470001],
#        [196.440002],
#        [185.889999],
#        [191.759995],
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
regressor.predict([[239,240,232.61]])
# Out:
# array([233.419998])

# %%
#svr

# %%
X_s = dataset.iloc[:, 1:2].values

# %%
X_s
# Out:
# array([[206.75    ],
#        [207.210007],
#        [206.699997],
#        [212.820007],
#        [213.      ],
#        [217.539993],
#        [219.199997],
#        [219.600006],
#        [221.610001],
#        [220.610001],
#        [222.570007],
#        [222.029999],
#        [222.160004],
#        [222.309998],
#        [220.75    ],
#        [220.800003],
#        [213.100006],
#        [216.139999],
#        [221.440002],
#        [206.529999],
#        [208.429993],
#        [203.440002],
#        [206.619995],
#        [212.509995],
#        [210.470001],
#        [210.300003],
#        [211.520004],
#        [210.190002],
#        [207.850006],
#        [209.520004],
#        [214.      ],
#        [213.550003],
#        [217.990005],
#        [216.520004],
#        [213.479996],
#        [201.800003],
#        [202.25    ],
#        [197.190002],
#        [191.820007],
#        [182.699997],
#        [194.029999],
#        [196.220001],
#        [189.169998],
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X_s = sc_X.fit_transform(X_s)
y_s = sc_y.fit_transform(y)

# %%
print(X_s)
# Out:
# [[ 0.16597773]
#  [ 0.18361491]
#  [ 0.16406056]
#  [ 0.3987085 ]
#  [ 0.40560963]
#  [ 0.57967797]
#  [ 0.64332435]
#  [ 0.65866114]
#  [ 0.73572656]
#  [ 0.69738546]
#  [ 0.77253425]
#  [ 0.75182975]
#  [ 0.75681428]
#  [ 0.76256522]
#  [ 0.70275318]
#  [ 0.70467035]
#  [ 0.40944397]
#  [ 0.52600065]
#  [ 0.72920861]
#  [ 0.15754265]
#  [ 0.23039052]
#  [ 0.03906876]
#  [ 0.1609932 ]
#  [ 0.38682229]
#  [ 0.30860667]
#  [ 0.30208876]
#  [ 0.34886495]
#  [ 0.2978712 ]
#  [ 0.20815317]
#  [ 0.27218274]
#  [ 0.44395073]
#  [ 0.42669735]
#  [ 0.59693192]
#  [ 0.54057046]
#  [ 0.4240132 ]
#  [-0.02381062]
#  [-0.00655723]
#  [-0.20056314]
#  [-0.40645467]
#  [-0.75612592]
#  [-0.32172114]
#  [-0.23775405]
#  [-0.50805894]
#  [-0.59969414]
#  [-0.92367635]
#  [-1.25839402]
#  [-1.06400494]
#  [-1.08931018]
#  [-1.64410602]
#  [-1.49112479]
#  [-1.92092825]
#  [-1.98150727]
#  [-2.40287619]
#  [-2.139473  ]
#  [-1.77906628]
#  [-2.0229157 ]
#  [-1.81012246]
#  [-1.66787731]
# ...

# %%
print(y_s)
# Out:
# [[ 0.26602681]
#  [ 0.22338492]
#  [ 0.37436045]
#  [ 0.39203154]
#  [ 0.47501041]
#  [ 0.59333203]
#  [ 0.58411198]
#  [ 0.73201415]
#  [ 0.62252807]
#  [ 0.70281753]
#  [ 0.72663589]
#  [ 0.74084965]
#  [ 0.71395851]
#  [ 0.70934877]
#  [ 0.64941921]
#  [ 0.5795022 ]
#  [ 0.46156454]
#  [ 0.57373944]
#  [ 0.78272307]
#  [ 0.25642279]
#  [-0.0363076 ]
#  [ 0.051281  ]
#  [ 0.26794773]
#  [ 0.2787042 ]
#  [ 0.3071323 ]
#  [ 0.36398795]
#  [ 0.39203154]
#  [ 0.16652926]
#  [ 0.30367443]
#  [ 0.39510487]
#  [ 0.43505737]
#  [ 0.57412399]
#  [ 0.56221508]
#  [ 0.45042415]
#  [ 0.28139302]
#  [-0.08202286]
#  [-0.23376629]
#  [-0.21724764]
#  [-0.50344738]
#  [-0.39895558]
#  [-0.24644368]
#  [-0.65173351]
#  [-0.42623123]
#  [-0.67939313]
#  [-0.83613085]
#  [-1.28137314]
#  [-0.94753727]
#  [-1.25294505]
#  [-1.8587669 ]
#  [-1.25140863]
#  [-2.18376723]
#  [-2.05276825]
#  [-2.14727148]
#  [-1.9102443 ]
#  [-2.04085934]
#  [-2.10347718]
#  [-1.60867836]
#  [-1.79192267]
# ...

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_s, y_s)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
sc_y.inverse_transform(regressor.predict(sc_X.transform([[233.42]])))
# Out:
# array([233.49434684])

# %%
plt.scatter(sc_X.inverse_transform(X_s), sc_y.inverse_transform(y_s), color = 'red')
plt.plot(sc_X.inverse_transform(X_s), sc_y.inverse_transform(regressor.predict(X_s)), color = 'blue')
plt.title('stock (support vector regression)')
plt.xlabel('open')
plt.ylabel('close')
plt.show()

# %%
X_grid = np.arange(min(sc_X.inverse_transform(X_s)), max(sc_X.inverse_transform(X_s)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X_s), sc_y.inverse_transform(y_s), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('stock (support Vector Regression)')
plt.xlabel('open')
plt.ylabel('close')
plt.show()

# %%
u = []

# %%
u.append(sc_y.inverse_transform(regressor.predict(sc_X.transform([[233.42]]))))

# %%
u
# Out:
# [array([233.49434684])]

# %%
u[0]
# Out:
# array([233.49434684])

# %%
for i in range(0,8):
    u.append(sc_y.inverse_transform(regressor.predict(sc_X.transform([u[i]]))))

# %%
u
# Out:
# [array([233.49434684]),
#  array([233.53228643]),
#  array([233.55146028]),
#  array([233.56110215]),
#  array([233.56593848]),
#  array([233.56836127]),
#  array([233.56957421]),
#  array([233.57018126]),
#  array([233.57048503])]
